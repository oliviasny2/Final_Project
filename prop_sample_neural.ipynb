# %%
import pandas as pd
from pathlib import Path
import numpy as np

# %%
# Load data
file_path = Path("SQL_cleaning_resources/action_taken_summary.csv")
df = pd.read_csv(file_path)
df.head(10)
# Out:
#   as_of_year  agency_code  loan_type  property_type  loan_purpose  \
# 0     7/9/05            9          1              1             1
# 1     7/9/05            2          1              1             3
# 2     7/9/05            9          1              1             3
# 3     7/9/05            7          1              1             3
# 4     7/9/05            7          1              1             1
# 5     7/9/05            9          2              1             3
# 6     7/9/05            9          1              1             3
# 7     7/9/05            9          1              1             1
# 8     7/9/05            7          1              1             1
# 9     7/9/05            9          1              1             1
#
#    owner_occupancy  loan_amount_000s  preapproval  action_taken  \
# 0                1               424            3             1
# 1                1               153            3             4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22903 entries, 0 to 22902
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   as_of_year                      22903 non-null  object
#  1   agency_code                     22903 non-null  int64
#  2   loan_type                       22903 non-null  int64
#  3   property_type                   22903 non-null  int64
#  4   loan_purpose                    22903 non-null  int64
#  5   owner_occupancy                 22903 non-null  int64
#  6   loan_amount_000s                22903 non-null  int64
#  7   preapproval                     22903 non-null  int64
#  8   action_taken                    22903 non-null  int64
#  9   action_taken_summary            19179 non-null  float64
#  10  msamd                           20076 non-null  float64
#  11  state_code                      22578 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# as_of_year                           0
# agency_code                          0
# loan_type                            0
# property_type                        0
# loan_purpose                         0
# owner_occupancy                      0
# loan_amount_000s                     0
# preapproval                          0
# action_taken                         0
# action_taken_summary              3724
# msamd                             2827
# state_code                         325
# county_code                        394
# census_tract_number                457
# applicant_ethnicity                  0
# co_applicant_ethnicity               0
# applicant_race_1                     0
# co_applicant_race_1                  0
# applicant_sex                        0
# co_applicant_sex                     0
# applicant_income_000s             3100
# purchaser_type                       0
# denial_reason_1                      0
# hoepa_status                         0
# ...

# %%
df.count()
# Out:
# as_of_year                        22903
# agency_code                       22903
# loan_type                         22903
# property_type                     22903
# loan_purpose                      22903
# owner_occupancy                   22903
# loan_amount_000s                  22903
# preapproval                       22903
# action_taken                      22903
# action_taken_summary              19179
# msamd                             20076
# state_code                        22578
# county_code                       22509
# census_tract_number               22446
# applicant_ethnicity               22903
# co_applicant_ethnicity            22903
# applicant_race_1                  22903
# co_applicant_race_1               22903
# applicant_sex                     22903
# co_applicant_sex                  22903
# applicant_income_000s             19803
# purchaser_type                    22903
# denial_reason_1                   22903
# ...

# %%
# drop the null values in the action taken summary column
df2 = df.dropna(axis=0, subset=['action_taken_summary'])
df2.head(10)
# Out:
#    as_of_year  agency_code  loan_type  property_type  loan_purpose  \
# 0      7/9/05            9          1              1             1
# 2      7/9/05            9          1              1             3
# 3      7/9/05            7          1              1             3
# 5      7/9/05            9          2              1             3
# 6      7/9/05            9          1              1             3
# 7      7/9/05            9          1              1             1
# 8      7/9/05            7          1              1             1
# 10     7/9/05            7          2              1             1
# 11     7/9/05            9          1              1             1
# 12     7/9/05            7          4              1             1
#
#     owner_occupancy  loan_amount_000s  preapproval  action_taken  \
# 0                 1               424            3             1
# 2                 1                56            3             3
# ...

# %%
df2.isnull().sum()
# Out:
# as_of_year                           0
# agency_code                          0
# loan_type                            0
# property_type                        0
# loan_purpose                         0
# owner_occupancy                      0
# loan_amount_000s                     0
# preapproval                          0
# action_taken                         0
# action_taken_summary                 0
# msamd                             2404
# state_code                         293
# county_code                        335
# census_tract_number                380
# applicant_ethnicity                  0
# co_applicant_ethnicity               0
# applicant_race_1                     0
# co_applicant_race_1                  0
# applicant_sex                        0
# co_applicant_sex                     0
# applicant_income_000s             2782
# purchaser_type                       0
# denial_reason_1                      0
# hoepa_status                         0
# ...

# %%
df2.count()
# Out:
# as_of_year                        19179
# agency_code                       19179
# loan_type                         19179
# property_type                     19179
# loan_purpose                      19179
# owner_occupancy                   19179
# loan_amount_000s                  19179
# preapproval                       19179
# action_taken                      19179
# action_taken_summary              19179
# msamd                             16775
# state_code                        18886
# county_code                       18844
# census_tract_number               18799
# applicant_ethnicity               19179
# co_applicant_ethnicity            19179
# applicant_race_1                  19179
# co_applicant_race_1               19179
# applicant_sex                     19179
# co_applicant_sex                  19179
# applicant_income_000s             16397
# purchaser_type                    19179
# denial_reason_1                   19179
# ...

# %%
df3 = df2.dropna()
df3.head(10)
# Out:
#    as_of_year  agency_code  loan_type  property_type  loan_purpose  \
# 0      7/9/05            9          1              1             1
# 2      7/9/05            9          1              1             3
# 3      7/9/05            7          1              1             3
# 7      7/9/05            9          1              1             1
# 10     7/9/05            7          2              1             1
# 11     7/9/05            9          1              1             1
# 13     7/9/05            2          3              1             1
# 14     7/9/05            9          1              1             1
# 16     7/9/05            9          1              1             1
# 18     7/9/05            9          1              1             1
#
#     owner_occupancy  loan_amount_000s  preapproval  action_taken  \
# 0                 1               424            3             1
# 2                 1                56            3             3
# ...

# %%
df3.isnull().sum()
# Out:
# as_of_year                        0
# agency_code                       0
# loan_type                         0
# property_type                     0
# loan_purpose                      0
# owner_occupancy                   0
# loan_amount_000s                  0
# preapproval                       0
# action_taken                      0
# action_taken_summary              0
# msamd                             0
# state_code                        0
# county_code                       0
# census_tract_number               0
# applicant_ethnicity               0
# co_applicant_ethnicity            0
# applicant_race_1                  0
# co_applicant_race_1               0
# applicant_sex                     0
# co_applicant_sex                  0
# applicant_income_000s             0
# purchaser_type                    0
# denial_reason_1                   0
# hoepa_status                      0
# lien_status                       0
# population                        0
# ...

# %%
df3.count()
# Out:
# as_of_year                        14289
# agency_code                       14289
# loan_type                         14289
# property_type                     14289
# loan_purpose                      14289
# owner_occupancy                   14289
# loan_amount_000s                  14289
# preapproval                       14289
# action_taken                      14289
# action_taken_summary              14289
# msamd                             14289
# state_code                        14289
# county_code                       14289
# census_tract_number               14289
# applicant_ethnicity               14289
# co_applicant_ethnicity            14289
# applicant_race_1                  14289
# co_applicant_race_1               14289
# applicant_sex                     14289
# co_applicant_sex                  14289
# applicant_income_000s             14289
# purchaser_type                    14289
# denial_reason_1                   14289
# ...

# %%
# export cleaned data to new csv file
save_path = "Resources/cleaned_action_summary.csv"
df3.to_csv(save_path, index=False)
