# %%
# import dependencies
import pandas as pd
import numpy as np
import pickle

# %%
# load data
df = pickle.load(open('Resources/final_pickle.pkl', 'rb'))

# %%
df.head()
# Out:
#     loan_amount_000s    msamd  county_code  census_tract_number  \
# 11              92.0  33860.0          1.0                201.0
# 13              94.0  33860.0          1.0                201.0
# 18             147.0  33860.0          1.0                201.0
# 24             115.0  33860.0          1.0                201.0
# 33             160.0  33860.0          1.0                201.0
#
#     applicant_income_000s  population  minority_population  \
# 11                   29.0      1948.0                12.58
# 13                   53.0      1948.0                12.58
# 18                   90.0      1948.0                12.58
# 24                   30.0      1948.0                12.58
# 33                   50.0      1948.0                12.58
#
#     hud_median_family_income  tract_to_msamd_income  \
# 11                   59700.0                 122.93
# 13                   59700.0                 122.93
# 18                   59700.0                 122.93
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 168940 entries, 11 to 1700351
# Data columns (total 59 columns):
#  #   Column                                                         Non-Null Count   Dtype
# ---  ------                                                         --------------   -----
#  0   loan_amount_000s                                               168940 non-null  float64
#  1   msamd                                                          168940 non-null  float64
#  2   county_code                                                    168940 non-null  float64
#  3   census_tract_number                                            168940 non-null  float64
#  4   applicant_income_000s                                          168940 non-null  float64
#  5   population                                                     168940 non-null  float64
#  6   minority_population                                            168940 non-null  float64
# ...

# %%
# Group approvals by whether or not someone was white based on loan amount
df.groupby(["action_taken_summary","applicant_race_1_White"])["loan_amount_000s"].describe()
# Out:
#                                                 count        mean         std  \
# action_taken_summary applicant_race_1_White
# 0                    0.0                       3967.0  296.779178  240.915498
#                      1.0                      17836.0  312.276407  247.673184
# 1                    0.0                      27069.0  297.263401  205.885174
#                      1.0                     120068.0  311.046707  216.329310
#
#                                              min    25%    50%    75%     max
# action_taken_summary applicant_race_1_White
# 0                    0.0                     3.0  135.0  228.0  390.0  1600.0
#                      1.0                     2.0  141.0  244.0  416.0  1650.0
# 1                    0.0                     1.0  162.0  245.0  385.0  1646.0
#                      1.0                     1.0  166.0  255.0  403.0  1650.0

# %%
# Group approvals by whether or not someone was hispanic based on loan amount
df.groupby(["action_taken_summary","applicant_ethnicity_Hispanic or Latino"])["loan_amount_000s"].describe()
# Out:
#                                                                 count  \
# action_taken_summary applicant_ethnicity_Hispanic or Latino
# 0                    0.0                                      19047.0
#                      1.0                                       2756.0
# 1                    0.0                                     128200.0
#                      1.0                                      18937.0
#
#                                                                    mean  \
# action_taken_summary applicant_ethnicity_Hispanic or Latino
# 0                    0.0                                     312.649919
#                      1.0                                     287.388244
# 1                    0.0                                     311.963760
#                      1.0                                     285.136241
#
#                                                                     std  min  \
# ...

# %%
# Group approvals by whether or not someone was hispanic based on income level
df.groupby(["action_taken_summary","applicant_ethnicity_Hispanic or Latino"])["applicant_income_000s"].describe()
# Out:
#                                                                 count  \
# action_taken_summary applicant_ethnicity_Hispanic or Latino
# 0                    0.0                                      19047.0
#                      1.0                                       2756.0
# 1                    0.0                                     128200.0
#                      1.0                                      18937.0
#
#                                                                    mean  \
# action_taken_summary applicant_ethnicity_Hispanic or Latino
# 0                    0.0                                     109.767207
#                      1.0                                     104.083454
# 1                    0.0                                     115.794493
#                      1.0                                     110.755399
#
#                                                                     std  min  \
# ...

# %%
# Group approvals by whether or not someone is white based on income level
df.groupby(["action_taken_summary","applicant_race_1_White"])["applicant_income_000s"].describe()
# Out:
#                                                 count        mean         std  \
# action_taken_summary applicant_race_1_White
# 0                    0.0                       3967.0  106.181245  158.061130
#                      1.0                      17836.0  109.686533  161.787928
# 1                    0.0                      27069.0  113.053825  136.957948
#                      1.0                     120068.0  115.617608  153.104847
#
#                                              min   25%   50%    75%      max
# action_taken_summary applicant_race_1_White
# 0                    0.0                     0.0  47.0  74.0  124.0   7180.0
#                      1.0                     0.0  48.0  78.0  127.0   7343.0
# 1                    0.0                     0.0  56.0  85.0  131.0   9999.0
#                      1.0                     0.0  57.0  87.0  135.0  18284.0

# %%
# Group approvals by whether or not someone was male based on loan amount
df.groupby(["action_taken_summary","applicant_sex_Male"])["loan_amount_000s"].describe()
# Out:
#                                             count        mean         std  \
# action_taken_summary applicant_sex_Male
# 0                    0.0                   6937.0  308.685166  245.037403
#                      1.0                  14866.0  309.816763  247.222746
# 1                    0.0                  46628.0  309.431586  215.957459
#                      1.0                 100509.0  308.083883  213.837658
#
#                                          min    25%    50%    75%     max
# action_taken_summary applicant_sex_Male
# 0                    0.0                 2.0  139.0  242.0  410.0  1650.0
#                      1.0                 2.0  140.0  240.0  412.0  1648.0
# 1                    0.0                 2.0  166.0  253.0  400.0  1650.0
#                      1.0                 1.0  165.0  253.0  400.0  1650.0

# %%
# Group approvals by whether or not someone was male based on income level
df.groupby(["action_taken_summary","applicant_sex_Male"])["applicant_income_000s"].describe()
# Out:
#                                             count        mean         std  \
# action_taken_summary applicant_sex_Male
# 0                    0.0                   6937.0  109.495027  162.381978
#                      1.0                  14866.0  108.840509  160.530355
# 1                    0.0                  46628.0  116.747684  172.486779
#                      1.0                 100509.0  114.402869  138.751123
#
#                                          min   25%   50%    75%      max
# action_taken_summary applicant_sex_Male
# 0                    0.0                 0.0  48.0  78.0  128.0   6000.0
#                      1.0                 0.0  48.0  77.0  126.0   7343.0
# 1                    0.0                 0.0  57.0  86.0  134.0  10365.0
#                      1.0                 0.0  57.0  86.0  134.0  18284.0

# %%
# Group approvals by whether or not someone was male based on income level
df.groupby(["action_taken_summary","applicant_sex_Male"])["msamd"].describe()
# Out:
#                                             count          mean           std  \
# action_taken_summary applicant_sex_Male
# 0                    0.0                   6937.0  27723.095863  12733.209134
#                      1.0                  14866.0  27941.381407  12699.986939
# 1                    0.0                  46628.0  29189.488934  12338.305056
#                      1.0                 100509.0  28956.845576  12413.877034
#
#                                          min      25%      50%      75%  \
# action_taken_summary applicant_sex_Male
# 0                    0.0                 0.0  19300.0  31084.0  38060.0
#                      1.0                 0.0  19340.0  31084.0  38060.0
# 1                    0.0                 0.0  22220.0  31084.0  38060.0
#                      1.0                 0.0  22220.0  31084.0  38060.0
#
#                                              max
# action_taken_summary applicant_sex_Male
# ...

# %%
# Group approvals by whether or not someone was hispanic based on income level
df.groupby(["action_taken_summary","applicant_ethnicity_Hispanic or Latino"])["msamd"].describe()
# Out:
#                                                                 count  \
# action_taken_summary applicant_ethnicity_Hispanic or Latino
# 0                    0.0                                      19047.0
#                      1.0                                       2756.0
# 1                    0.0                                     128200.0
#                      1.0                                      18937.0
#
#                                                                      mean  \
# action_taken_summary applicant_ethnicity_Hispanic or Latino
# 0                    0.0                                     28123.031449
#                      1.0                                     26136.542816
# 1                    0.0                                     29278.157207
#                      1.0                                     27354.455722
#
#                                                                       std  \
# ...

# %%
# Group approvals by whether or not someone was white based on income level
df.groupby(["action_taken_summary","applicant_race_1_White"])["msamd"].describe()
# Out:
#                                                 count          mean  \
# action_taken_summary applicant_race_1_White
# 0                    0.0                       3967.0  27268.189564
#                      1.0                      17836.0  28006.211258
# 1                    0.0                      27069.0  28158.218553
#                      1.0                     120068.0  29227.240097
#
#                                                       std  min      25%  \
# action_taken_summary applicant_race_1_White
# 0                    0.0                     12666.709734  0.0  19300.0
#                      1.0                     12716.898454  0.0  19300.0
# 1                    0.0                     12552.987333  0.0  19460.0
#                      1.0                     12345.000830  0.0  22220.0
#
#                                                  50%      75%      max
# action_taken_summary applicant_race_1_White
# ...

# %%
# Group approvals by whether or not someone was male based on income level
df.groupby(["action_taken_summary","applicant_sex_Male"])["population"].describe()
# Out:
#                                             count         mean          std  \
# action_taken_summary applicant_sex_Male
# 0                    0.0                   6937.0  5593.320167  2603.813111
#                      1.0                  14866.0  5590.296583  2523.652047
# 1                    0.0                  46628.0  5644.557154  2521.505590
#                      1.0                 100509.0  5693.252246  2555.787579
#
#                                           min      25%     50%     75%  \
# action_taken_summary applicant_sex_Male
# 0                    0.0                 10.0  3896.00  5145.0  6707.0
#                      1.0                 93.0  3931.00  5178.0  6697.0
# 1                    0.0                 45.0  3989.75  5233.5  6712.0
#                      1.0                 41.0  4009.00  5279.0  6776.0
#
#                                              max
# action_taken_summary applicant_sex_Male
# 0                    0.0                 22185.0
# ...

# %%
# Group approvals by whether or not someone was hispanic based on income level
df.groupby(["action_taken_summary","applicant_ethnicity_Hispanic or Latino"])["population"].describe()
# Out:
#                                                                 count  \
# action_taken_summary applicant_ethnicity_Hispanic or Latino
# 0                    0.0                                      19047.0
#                      1.0                                       2756.0
# 1                    0.0                                     128200.0
#                      1.0                                      18937.0
#
#                                                                     mean  \
# action_taken_summary applicant_ethnicity_Hispanic or Latino
# 0                    0.0                                     5582.874206
#                      1.0                                     5649.203919
# 1                    0.0                                     5666.191349
#                      1.0                                     5756.549084
#
#                                                                      std  \
# ...

# %%
# Group approvals by whether or not someone was white based on income level
df.groupby(["action_taken_summary","applicant_race_1_White"])["population"].describe()
# Out:
#                                                 count         mean  \
# action_taken_summary applicant_race_1_White
# 0                    0.0                       3967.0  5593.270734
#                      1.0                      17836.0  5590.811056
# 1                    0.0                      27069.0  5683.666593
#                      1.0                     120068.0  5676.502732
#
#                                                      std   min     25%  \
# action_taken_summary applicant_race_1_White
# 0                    0.0                     2628.892977  93.0  3833.5
#                      1.0                     2531.419389  10.0  3939.0
# 1                    0.0                     2581.322959  93.0  3993.0
#                      1.0                     2536.829172  41.0  4004.0
#
#                                                 50%     75%      max
# action_taken_summary applicant_race_1_White
# 0                    0.0                     5083.0  6707.0  22185.0
# ...

# %%
# Group approvals by whether or not someone was male based on income level
df.groupby(["action_taken_summary","applicant_sex_Male"])["minority_population"].describe()
# Out:
#                                             count       mean        std  min  \
# action_taken_summary applicant_sex_Male
# 0                    0.0                   6937.0  45.235311  28.111686  0.0
#                      1.0                  14866.0  45.247740  27.880115  0.0
# 1                    0.0                  46628.0  42.463258  26.364038  0.0
#                      1.0                 100509.0  42.775008  26.359251  0.0
#
#                                            25%    50%    75%    max
# action_taken_summary applicant_sex_Male
# 0                    0.0                 21.66  39.30  69.56  100.0
#                      1.0                 22.07  39.07  69.31  100.0
# 1                    0.0                 21.26  36.31  61.33  100.0
#                      1.0                 21.69  36.62  62.11  100.0

# %%
# Group approvals by whether or not someone was hispanic based on income level
df.groupby(["action_taken_summary","applicant_ethnicity_Hispanic or Latino"])["minority_population"].describe()
# Out:
#                                                                 count  \
# action_taken_summary applicant_ethnicity_Hispanic or Latino
# 0                    0.0                                      19047.0
#                      1.0                                       2756.0
# 1                    0.0                                     128200.0
#                      1.0                                      18937.0
#
#                                                                   mean  \
# action_taken_summary applicant_ethnicity_Hispanic or Latino
# 0                    0.0                                     45.649532
#                      1.0                                     42.439634
# 1                    0.0                                     43.107263
#                      1.0                                     39.758093
#
#                                                                    std  min  \
# ...

# %%
# Group approvals by whether or not someone was white based on income level
df.groupby(["action_taken_summary","applicant_race_1_White"])["minority_population"].describe()
# Out:
#                                                 count       mean        std  \
# action_taken_summary applicant_race_1_White
# 0                    0.0                       3967.0  42.488790  27.417301
#                      1.0                      17836.0  45.856539  28.035168
# 1                    0.0                      27069.0  40.128884  25.862928
#                      1.0                     120068.0  43.250502  26.438313
#
#                                              min      25%     50%      75%  \
# action_taken_summary applicant_race_1_White
# 0                    0.0                     0.0  19.7700  36.040  65.6100
#                      1.0                     0.0  22.4900  40.415  70.1100
# 1                    0.0                     0.0  19.9200  33.920  57.3300
#                      1.0                     0.0  21.9475  37.240  62.8725
#
#                                                max
# action_taken_summary applicant_race_1_White
# ...

# %%
# Group approvals by whether or not someone was male based on income level
df.groupby(["action_taken_summary","applicant_sex_Male"])["hud_median_family_income"].describe()
# Out:
#                                             count          mean           std  \
# action_taken_summary applicant_sex_Male
# 0                    0.0                   6937.0  65619.561770  13228.016711
#                      1.0                  14866.0  65886.795372  13557.185377
# 1                    0.0                  46628.0  66489.433388  13218.918756
#                      1.0                 100509.0  66617.259151  13346.584895
#
#                                              min      25%      50%      75%  \
# action_taken_summary applicant_sex_Male
# 0                    0.0                 44500.0  59700.0  64300.0  66200.0
#                      1.0                 44500.0  59300.0  64300.0  66200.0
# 1                    0.0                 44500.0  59900.0  64300.0  66200.0
#                      1.0                 44500.0  59900.0  64300.0  66200.0
#
#                                               max
# action_taken_summary applicant_sex_Male
# ...

# %%
# Group approvals by whether or not someone was hispanic based on income level
df.groupby(["action_taken_summary","applicant_ethnicity_Hispanic or Latino"])["hud_median_family_income"].describe()
# Out:
#                                                                 count  \
# action_taken_summary applicant_ethnicity_Hispanic or Latino
# 0                    0.0                                      19047.0
#                      1.0                                       2756.0
# 1                    0.0                                     128200.0
#                      1.0                                      18937.0
#
#                                                                      mean  \
# action_taken_summary applicant_ethnicity_Hispanic or Latino
# 0                    0.0                                     65940.389563
#                      1.0                                     64843.759071
# 1                    0.0                                     66732.563963
#                      1.0                                     65521.925331
#
#                                                                       std  \
# ...

# %%
# Group approvals by whether or not someone was white based on income level
df.groupby(["action_taken_summary","applicant_race_1_White"])["hud_median_family_income"].describe()
# Out:
#                                                 count          mean  \
# action_taken_summary applicant_race_1_White
# 0                    0.0                       3967.0  65433.098059
#                      1.0                      17836.0  65883.768782
# 1                    0.0                      27069.0  66559.485020
#                      1.0                     120068.0  66580.643469
#
#                                                       std      min      25%  \
# action_taken_summary applicant_race_1_White
# 0                    0.0                     13374.527616  44500.0  59300.0
#                      1.0                     13470.126623  44500.0  59700.0
# 1                    0.0                     13091.163679  44500.0  59900.0
#                      1.0                     13354.432312  44500.0  59900.0
#
#                                                  50%      75%       max
# action_taken_summary applicant_race_1_White
# ...
