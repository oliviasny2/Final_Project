# %%
import pandas as pd
from pathlib import Path
import numpy as np
import pickle

# %%
# Load data
file_path = Path("Resources/cleaned_raws.csv")
df = pd.read_csv(file_path)

# %%
# Create Index with respondent_id
df = df.set_index('respondent_id')
df.head(10)
# Out:
#               agency_code      loan_type       property_type  \
# respondent_id
# 0000342634           CFPB   Conventional  One to Four-Family
# 0004186591           CFPB  VA-Guaranteed  One to Four-Family
# 22-3039688            HUD  VA-Guaranteed  One to Four-Family
# 20-3878295           NCUA   Conventional  One to Four-Family
# 0000342634           CFPB   Conventional  One to Four-Family
# 68-0309242            HUD  VA-Guaranteed  One to Four-Family
# 0000013303           FDIC    FHA-Insured  One to Four-Family
# 0000808176           CFPB   Conventional  One to Four-Family
# 3027509990            HUD  VA-Guaranteed  One to Four-Family
# 0471809999            HUD   Conventional  One to Four-Family
#
#                    loan_purpose     owner_occupancy  loan_amount_000s  \
# respondent_id
# 0000342634          Refinancing      Owner Occupied               9.0
# 0004186591        Home Purchase      Owner Occupied              94.0
# ...

# %%
# Save File
pickle.dump(df, open('pickled_raws.pkl', 'wb'))
